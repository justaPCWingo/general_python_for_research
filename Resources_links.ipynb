# %% [markdown]
# # Useful Urls:
#
# * [Official Python 3 tutorial](https://docs.python.org/3/tutorial/)
# * [Basics of Python 2 at Tutorials Point](https://www.tutorialspoint.com/python/)
# * [w3 Schools Python Tutorials (server-focused)](https://www.w3schools.com/python/default.asp)
# * [Learn Python - focuses on python 3, and has some useful data sciences sections](https://www.learnpython.org/)

# %% [markdown]
# # Outline:
# ## Part 1: The basics
#
# * **Introduction**
#   * What is Python?
#   * Why is it useful?
#   * Python 2 vs Python 3.
#   * Download and installation.
#   * Uses in data science & GIS.
#   * Where to find help
#   * Useful tools
# * **The basics**
#   * Hello World!
#   * The interpreter vs the language.
#   * indentation matters!
#     * The `pass` keyword
#   * basic variables & types
#   * strings
#   * i/o
# * **Containers**
#   * Tuples
#   * Lists
#   * Dictionaries
#   * Sets
# * **Control structures**
#   * If, else, elif
#   * while loop
#   * for loop
#     * range()
# * **Functions**
#   * Calling Functions
#     * position arguments
#     * keyword arguments
#   * Declaring Functions
#     * default arguments
#     * capture syntax
#     * return values
# * **Aside** *code documentation*
#   * Docstrings
# * **Exceptions**
#   * Why use exceptions?
#   * Catching Exceptions
#     * When to catch?
#     * try ... except blocks
#     * finally & else
#   * raise your own exceptions
#     * Why?
#     * raise keyword
#     * Use existing exceptions
#     * Create your own exceptions
# * **The import statement**
#   * Modules
#   * packages
#   * The `if __name__ == '__main__':` clause
#
# ## Part 2: Object Oriented Programming
# * **Introduction**
#   * What is _Object Oriented Programming?_
#     * Behaviors
#     * Attributes
#     * Encapsulation
#     * Inheritance
#     * Permissions
#   * The `class` object
#     * Instancing
#     * Behaviors and Attributes
#   * Examples
# * **Python Classes**
#   * Class object structure
#   * `self` variable
#   * Magic methods
#   * Initialization and destruction
#   * invocations
#   * permissions
#   * object vs class vs static levels
#   * ...
# * **Decorators and Classes**
#   * What is a decorator?
#     * Common decorators in OOP
#       * `@property`
#       * `@classmethod`
#       * `@staticmethod`
#   * Declaring properties
#     * Why?
#     * Getters
#     * Setters
#   * class and static methods
#     * When to use class methods.
#     * When to use static methods.
# * **Class inheritance**
#   * Why is inheritance useful?
#   * Inheritance in Python
#     * Declaring Inheritance
#        * subclassing
#        * inherited methods and attributes
#        * overriding parent methods
#        * Interfaces?
#     * Multiple inheritance
#        * Diamond of death
#     * AbstractBaseClass: a useful tool
#       * Build "contracts" ie protocals or interfaces.
#       * Optional, but useful.
#  * Inheritance diagrams
# * **Example implementations**
#   * Fuzzy Logic package
#   * Custom wx dialogs.
#     * Example with wxFormBuilder?
#   * ...
